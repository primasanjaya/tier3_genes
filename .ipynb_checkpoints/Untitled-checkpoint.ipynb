# %%
import pandas as pd

# %%
pd_driver = pd.read_csv('../CancerMutationCensus_AllData_v99_GRCh38.tsv',sep='\t',low_memory=False)

# %%
pd_driver.columns
# Out:
# Index(['GENE_NAME', 'ACCESSION_NUMBER', 'ONC_TSG', 'CGC_TIER', 'MUTATION_URL',
#        'LEGACY_MUTATION_ID', 'Mutation CDS', 'Mutation AA', 'AA_MUT_START',
#        'AA_MUT_STOP', 'SHARED_AA', 'GENOMIC_WT_ALLELE_SEQ',
#        'GENOMIC_MUT_ALLELE_SEQ', 'AA_WT_ALLELE_SEQ', 'AA_MUT_ALLELE_SEQ',
#        'Mutation Description CDS', 'Mutation Description AA',
#        'ONTOLOGY_MUTATION_CODE', 'GENOMIC_MUTATION_ID',
#        'Mutation genome position GRCh37', 'Mutation genome position GRCh38',
#        'COSMIC_SAMPLE_TESTED', 'COSMIC_SAMPLE_MUTATED', 'DISEASE',
#        'WGS_DISEASE', 'EXAC_AF', 'EXAC_AFR_AF', 'EXAC_AMR_AF', 'EXAC_ADJ_AF',
#        'EXAC_EAS_AF', 'EXAC_FIN_AF', 'EXAC_NFE_AF', 'EXAC_SAS_AF',
#        'GNOMAD_EXOMES_AF', 'GNOMAD_EXOMES_AFR_AF', 'GNOMAD_EXOMES_AMR_AF',
#        'GNOMAD_EXOMES_ASJ_AF', 'GNOMAD_EXOMES_EAS_AF', 'GNOMAD_EXOMES_FIN_AF',
#        'GNOMAD_EXOMES_NFE_AF', 'GNOMAD_EXOMES_SAS_AF', 'GNOMAD_GENOMES_AF',
#        'GNOMAD_GENOMES_AFR_AF', 'GNOMAD_GENOMES_AMI_AF',
#        'GNOMAD_GENOMES_AMR_AF', 'GNOMAD_GENOMES_ASJ_AF',
#        'GNOMAD_GENOMES_EAS_AF', 'GNOMAD_GENOMES_FIN_AF',
#        'GNOMAD_GENOMES_MID_AF', 'GNOMAD_GENOMES_NFE_AF',
#        'GNOMAD_GENOMES_SAS_AF', 'CLINVAR_CLNSIG', 'CLINVAR_TRAIT', 'GERP++_RS',
#        'MIN_SIFT_SCORE', 'MIN_SIFT_PRED', 'DNDS_DISEASE_QVAL_SIG',
#        'MUTATION_SIGNIFICANCE_TIER'],
#       dtype='object')

# %%
pd_tier = pd_driver.loc[pd_driver['MUTATION_SIGNIFICANCE_TIER'].isin(['1','2','3'])]

# %%
pd_tier = pd_tier.loc[~pd_tier['ONC_TSG'].isna()]

# %%
pd_tier = pd_tier[['GENE_NAME','ONC_TSG','CGC_TIER','MUTATION_SIGNIFICANCE_TIER','Mutation genome position GRCh37', 'Mutation genome position GRCh38']]

# %%
pd_tier.to_csv('all_tier.csv')

# %%
pd_driver_small = pd_driver[['GENE_NAME','ONC_TSG','CGC_TIER','MUTATION_SIGNIFICANCE_TIER','Mutation genome position GRCh37', 'Mutation genome position GRCh38']]

# %%
pd_driver_small = pd_driver_small.loc[~pd_driver_small['ONC_TSG'].isna()]

# %%
pd_driver_small = pd_driver_small.loc[pd_driver_small['MUTATION_SIGNIFICANCE_TIER'].isin(['1','2','3'])]

# %%
pd_driver_small = pd_driver_small.reset_index(drop=True)

# %%
pd_driver_small.to_csv('cosmic_census.csv')

# %%
pd_driver_tsgonc = pd_driver.loc[pd_driver['ONC_TSG'].isin(['oncogene, TSG, fusion'])]

# %%
pd_driver_tsgonc
# Out:
#         GENE_NAME   ACCESSION_NUMBER                ONC_TSG  CGC_TIER  \
# 186121       ESR1  ENST00000440973.1  oncogene, TSG, fusion       1.0
# 186122       ESR1  ENST00000440973.1  oncogene, TSG, fusion       1.0
# 186123       ESR1  ENST00000440973.1  oncogene, TSG, fusion       1.0
# 186124       ESR1  ENST00000440973.1  oncogene, TSG, fusion       1.0
# 186125       ESR1  ENST00000440973.1  oncogene, TSG, fusion       1.0
# ...           ...                ...                    ...       ...
# 4936271    CREBBP  ENST00000262367.5  oncogene, TSG, fusion       1.0
# 4936272    CREBBP  ENST00000262367.5  oncogene, TSG, fusion       1.0
# 4936273    CREBBP  ENST00000262367.5  oncogene, TSG, fusion       1.0
# 4936274    CREBBP  ENST00000262367.5  oncogene, TSG, fusion       1.0
# 4936275    CREBBP  ENST00000262367.5  oncogene, TSG, fusion       1.0
#
#                                               MUTATION_URL LEGACY_MUTATION_ID  \
# 186121   https://cancer.sanger.ac.uk/cosmic/mutation/ov...        COSM6959903
# 186122   https://cancer.sanger.ac.uk/cosmic/mutation/ov...       COSM10000648
# 186123   https://cancer.sanger.ac.uk/cosmic/mutation/ov...        COSM8552626
# 186124   https://cancer.sanger.ac.uk/cosmic/mutation/ov...       COSM10252331
# 186125   https://cancer.sanger.ac.uk/cosmic/mutation/ov...       COSM10267424
# ...                                                    ...                ...
# 4936271  https://cancer.sanger.ac.uk/cosmic/mutation/ov...        COSM6635352
# 4936272  https://cancer.sanger.ac.uk/cosmic/mutation/ov...        COSM6983531
# 4936273  https://cancer.sanger.ac.uk/cosmic/mutation/ov...        COSM6929705
# 4936274  https://cancer.sanger.ac.uk/cosmic/mutation/ov...          COSM88752
# 4936275  https://cancer.sanger.ac.uk/cosmic/mutation/ov...        COSM4060702
#
#                 Mutation CDS Mutation AA  AA_MUT_START  AA_MUT_STOP  ...  \
# 186121               c.94A>C      p.K32Q            32           32  ...
# 186122             c.1567G>A     p.E523K           523          523  ...
# 186123              c.388T>C     p.Y130H           130          130  ...
# 186124   c.1671_1672delinsTT     p.A558S           558          558  ...
# 186125             c.1756G>T     p.G586W           586          586  ...
# ...                      ...         ...           ...          ...  ...
# 4936271            c.4111G>T    p.V1371F          1371         1371  ...
# 4936272            c.6760C>T    p.L2254F          2254         2254  ...
# 4936273            c.2116G>A     p.G706R           706          706  ...
# 4936274            c.4496T>C    p.L1499P          1499         1499  ...
# 4936275            c.4948G>A    p.V1650I          1650         1650  ...
#
#          GNOMAD_GENOMES_MID_AF GNOMAD_GENOMES_NFE_AF GNOMAD_GENOMES_SAS_AF  \
# 186121                     NaN                   NaN                   NaN
# 186122                     NaN                   NaN                   NaN
# 186123                     NaN                   NaN                   NaN
# 186124                     NaN                   NaN                   NaN
# 186125                     NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 4936271                    NaN                   NaN                   NaN
# 4936272                    NaN                   NaN                   NaN
# 4936273                    NaN                   NaN                   NaN
# 4936274                    NaN                   NaN                   NaN
# 4936275                    0.0              0.000059                   0.0
#
#         CLINVAR_CLNSIG CLINVAR_TRAIT GERP++_RS MIN_SIFT_SCORE MIN_SIFT_PRED  \
# 186121             NaN           NaN      5.06          0.000             D
# 186122             NaN           NaN      5.31          0.001             D
# 186123             NaN           NaN      4.89          0.000             D
# 186124             NaN           NaN       NaN          1.000           NaN
# 186125             NaN           NaN      3.53          0.012             D
# ...                ...           ...       ...            ...           ...
# 4936271            NaN           NaN      4.31          0.017             D
# 4936272            NaN           NaN      4.07          0.061             T
# 4936273            NaN           NaN      4.68          0.011             D
# 4936274            NaN           NaN      5.25          0.000             D
# 4936275  Likely benign  not provided      4.93          0.175             T
#
#         DNDS_DISEASE_QVAL_SIG MUTATION_SIGNIFICANCE_TIER
# 186121                    NaN                      Other
# 186122                    NaN                      Other
# 186123                    NaN                      Other
# 186124                    NaN                      Other
# 186125                    NaN                      Other
# ...                       ...                        ...
# 4936271                   NaN                      Other
# 4936272                   NaN                      Other
# 4936273                   NaN                      Other
# 4936274                   NaN                      Other
# 4936275                   NaN                      Other
#
# [24503 rows x 58 columns]

# %%
pd_driver_tsgonc['GENE_NAME'].unique()
# Out:
# array(['ESR1', 'ARNT', 'NFKB2', 'RUNX1', 'FOXO1', 'TET1', 'TCF3', 'FOXO4',
#        'NTRK1', 'BIRC3', 'CIC', 'HOXA11', 'FOXO3', 'TRIM24', 'CBL',
#        'TP53', 'IKZF3', 'MRTFA', 'ELF4', 'HOXA9', 'RUNX1T1', 'TBL1XR1',
#        'WT1', 'BCL11B', 'SUZ12', 'STAT5B', 'PRKAR1A', 'IRF4', 'NOTCH1',
#        'PAX5', 'CREBBP'], dtype=object)
