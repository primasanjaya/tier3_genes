# %%
import pandas as pd

# %%
pd_driver = pd.read_csv('../CancerMutationCensus_AllData_v99_GRCh38.tsv',sep='\t',low_memory=False)

# %%
pd_driver['ONC_TSG'].unique()
# Out:
# array([nan, 'TSG, fusion', 'oncogene, TSG', 'oncogene', 'TSG',
#        'oncogene, fusion', 'fusion', 'oncogene, TSG, fusion'],
#       dtype=object)

# %%
pd_driver_tsgonc = pd_driver.loc[pd_driver['ONC_TSG'].isin(['oncogene','TSG'])]

# %%
pd_driver_tsgonc
# Out:
#         GENE_NAME   ACCESSION_NUMBER   ONC_TSG  CGC_TIER  \
# 25467        MDM4  ENST00000367182.3  oncogene       1.0
# 25468        MDM4  ENST00000367182.3  oncogene       1.0
# 25469        MDM4  ENST00000367182.3  oncogene       1.0
# 25470        MDM4  ENST00000367182.3  oncogene       1.0
# 25471        MDM4  ENST00000367182.3  oncogene       1.0
# ...           ...                ...       ...       ...
# 5202625     MYD88  ENST00000417037.2  oncogene       1.0
# 5202626     MYD88  ENST00000417037.2  oncogene       1.0
# 5202627     MYD88  ENST00000417037.2  oncogene       1.0
# 5202628     MYD88  ENST00000417037.2  oncogene       1.0
# 5202629     MYD88  ENST00000417037.2  oncogene       1.0
#
#                                               MUTATION_URL LEGACY_MUTATION_ID  \
# 25467    https://cancer.sanger.ac.uk/cosmic/mutation/ov...        COSM6949631
# 25468    https://cancer.sanger.ac.uk/cosmic/mutation/ov...        COSM5845209
# ...
